# %% [markdown]
# # Download roboflow dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="")
project = rf.workspace("test-lnqpo").project("power_meter")
dataset = project.version(10).download("yolov5")

# %% [markdown]
# ## Example training scipt
#
# python train.py --img 1280 --batch 3 --epochs 200 --data /home/asus/Documents/GitHub/yolov5/Power_Meter-10/data.yaml --weights /home/asus/Documents/GitHub/yolov5/yolov5s-svhn.pt
